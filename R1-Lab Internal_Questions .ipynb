# %% [markdown]
# ## Lists, Dictionaries and Sets in Python

# %% [markdown]
# ## Part 1
#
# ### Lists in Python
#
# Sequences in Python are data structures that hold objects in an ordered array. Now, we will work on Lists, the most common sequence data types in Python.

# %%
#Example 
l1 = ['learning', "Python", 'is fun?', True]
print(l1)
# Out:
# ['learning', 'Python', 'is fun?', True]

# %% [markdown]
# List can also be created by using list() function.

# %%
#Example
l2 = list(("learning", "for", "life", True))
print(l2)
# Out:
# ['learning', 'for', 'life', True]

# %% [markdown]
# Adding to an existing list
#
# ### Question 1
#
# Add 10 to list l1 given above.
#
# [ **Hint: ** Use **append** ]

# %%
l1 = ['learning', "Python", 'is fun?', True]
l1.append("10")
print(l1)
# Out:
# ['learning', 'Python', 'is fun?', True, '10']

# %% [markdown]
# Removing from an existing list
#
# ### Question 2
#
# Remove 10 from l1.
#
# [ **Hint:** Use **remove**]

# %%
l1 = ['learning', "Python", 'is fun?', True, '10' ]
l1.remove("10")
print(l1)
# Out:
# ['learning', 'Python', 'is fun?', True]

# %% [markdown]
# Joining 2 lists
#
# ### Question 3
#
# [ **Hint: ** Use **+** operator or **extend**]

# %%
l1 = ['learning', "Python", 'is fun?', True]
l2 = list(("learning", "for", "life", True))

# %%
print (l1)
l1.extend(l2)
print (l1)
# Out:
# ['learning', 'Python', 'is fun?', True, 'l', 'e', 'a', 'r', 'n', 'i', 'n', 'g', 'l', 'e', 'a', 'r', 'n', 'i', 'n', 'g']
# ['learning', 'Python', 'is fun?', True, 'l', 'e', 'a', 'r', 'n', 'i', 'n', 'g', 'l', 'e', 'a', 'r', 'n', 'i', 'n', 'g', 'learning', 'for', 'life', True]

# %% [markdown]
# Number List
#
# ### Question 4
#
# Find Range and Mean of l3.
#
# l3 = [2,4,6,8]
#
# [ **Hint: ** Use **len(),sum(), min(), max()** functions ]
#
# If you want to use standard functions like mean & range, you have to import them from numpy else you can calculate them the traditional way using formulas

# %%
l3 = [2,4,6,8]
print('Range of l3 is:', max(l3) - min(l3))
# Out:
# Range of l3 is: 6

# %%
l3 = [2,4,6,8]
print('Mean of l3 is:', sum(l3) / len(l3))
# Out:
# Mean of l3 is: 5.0

# %% [markdown]
# Count the occurances of an element in a given list.
#
# ### Question 5
# Append the given sequence of numbers to l3 (given above) 0,1,3,3,5,5,7,9. Count the occurences of 5 in l3.
#
# [ **Hint: ** Use ** + operator to add multiple elements in the array and count() function to print the occurences**]

# %%
l3 = [2,4,6,8]
print("Print before append:" , l3)
l3.extend([0, 1, 3, 3, 5, 5, 7, 9])
print("Print after append:" , l3)
print("Occurences of 5 in l3:" ,l3.count(5))
# Out:
# Print before append: [2, 4, 6, 8]
# Print after append: [2, 4, 6, 8, 0, 1, 3, 3, 5, 5, 7, 9]
# Occurences of 5 in l3: 2

# %% [markdown]
# Sorting and Reversing a list
#
# ### Question 6
# sort and print l3 in ascending and descending order sequentially (given above)
#
# **(Hint: Use .sort() function)**

# %%
l3 = [2,4,6,8]
l3.extend([0, 1, 3, 3, 5, 5, 7, 9])
print("Before sort:" , l3)
l3.sort()
print(l3)
print("After sort:Ascending:" , l3)
print(l3)
l3.sort(reverse=True)
print("After sort:Descending:" , l3)
# Out:
# Before sort: [2, 4, 6, 8, 0, 1, 3, 3, 5, 5, 7, 9]
# [0, 1, 2, 3, 3, 4, 5, 5, 6, 7, 8, 9]
# After sort:Ascending: [0, 1, 2, 3, 3, 4, 5, 5, 6, 7, 8, 9]
# [0, 1, 2, 3, 3, 4, 5, 5, 6, 7, 8, 9]
# After sort:Descending: [9, 8, 7, 6, 5, 5, 4, 3, 3, 2, 1, 0]

# %% [markdown]
# ### Functions

# %% [markdown]
# **Example:**
#
# **def** function_name(args)**:**
#
#     function code goes here

# %% [markdown]
# ### Question 7
#
# Define a function with name **sum_3** which can take 3 numbers as input, and returns sum of them.

# %%
def  sum_3(a=0,b=0,c=0):
    sum=a+b+c;
    return sum;

num1=5
num2=55
num3=35
print("The sum is",sum_3(num1,num2,num3))
# Out:
# The sum is 95

# %% [markdown]
# ### Lambda Functions

# %% [markdown]
# Anonymous functions or no name functions, which can be considered when you use a function only once.
#
# **Example:**
#
# f = lambda x, y : x + y
#
# f(1,1)
#
# 2

# %% [markdown]
# ### Question 8
#
# Write the same above **sum_3** function using lambda.

# %%
f = lambda x, y, z : x + y + z
f(5,55,35)
# Out:
# 95

# %% [markdown]
# # Numpy

# %% [markdown]
# We have seen python basic data structures in our last section. They are great but lack specialized features for data analysis. Like, adding roows, columns, operating on 2d matrices aren't readily available. So, we will use *numpy* for such functions.

# %%
import numpy as np

# %% [markdown]
# Numpy operates on *nd* arrays. These are similar to lists but contains homogenous elements but easier to store 2-d data.

# %%
l1 = [1,2,3,4]
nd1 = np.array(l1)
print(nd1)

l2 = [5,6,7,8]
nd2 = np.array([l1,l2])
print(nd2)
# Out:
# [1 2 3 4]
# [[1 2 3 4]
#  [5 6 7 8]]

# %% [markdown]
# Sum functions on np.array()

# %%
print(nd2.shape)

print(nd2.size)

print(nd2.dtype)
# Out:
# (2L, 4L)
# 8
# int32

# %% [markdown]
# ### Question 1
#
# Create an identity 2d-array or matrix (with ones across the diagonal).
#
# [ **Hint: ** You can also use **np.identity()** function ]

# %%
 np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# ### Question 2
#
# Create a 2d-array or matrix of order 3x3 with values = 9,8,7,6,5,4,3,2,1 arranged in the same order.
#
# Use: **np.matrix()** function

# %%
mtx = np.matrix('9 8 7;6 5 4;3 2 1')
print(mtx)
# Out:
# [[9 8 7]
#  [6 5 4]
#  [3 2 1]]

# %% [markdown]
# ### Question 3
#
# Reverse both the rows and columns of the given matrix.
#
# Hint: You can use the transpose **.T**)

# %%
mtx = np.matrix('9 8 7;6 5 4;3 2 1')
print("Matrix:\n", mtx)
print("Tranpose Matrix:\n", np.transpose(mtx))
# Out:
# Matrix:
#  [[9 8 7]
#  [6 5 4]
#  [3 2 1]]
# Tranpose Matrix:
#  [[9 6 3]
#  [8 5 2]
#  [7 4 1]]

# %% [markdown]
# ### Question 4
# Add + 1 to all the elements in the given matrix.

# %%
mtx = np.matrix('9 8 7;6 5 4;3 2 1')
mtx1 = np.matrix('1 1 1;1 1 1;1 1 1')
print("Matrix:\n", mtx)
print ("Matrix with + 1:\n", mtx + 1)
print ("Matrix with + 1:\n", np.add(mtx,mtx1))
# Out:
# Matrix:
#  [[9 8 7]
#  [6 5 4]
#  [3 2 1]]
# Matrix with + 1:
#  [[10  9  8]
#  [ 7  6  5]
#  [ 4  3  2]]
# Matrix with + 1:
#  [[10  9  8]
#  [ 7  6  5]
#  [ 4  3  2]]

# %% [markdown]
# Similarly you can do operations like scalar  substraction, division, multiplication (operating on each element in the matrix)

# %% [markdown]
# ### Question 5
#
# Find the mean of all elements in the given matrix nd6.
# nd6 = [[  1   4   9 121 144 169]
#  [ 16  25  36 196 225 256]
#  [ 49  64  81 289 324 361]]
#
#  Use: **.mean()** function

# %%
nd6 = np.matrix('1 4 9 121 144 169;16 25 36 196 225 256; 49 64 81 289 324 361')
print(np.mean(nd6))
# Out:
# 131.66666666666666

# %% [markdown]
# ### Question 7
#
# Find the dot product of two given matrices.
#
# [**Hint:** Use **np.dot()**]

# %%
mtx = np.matrix('9 8 7;6 5 4;3 2 1')
mtx1 = np.matrix('1 1 1;1 1 1;1 1 1')
print(np.dot(mtx,mtx1))
# Out:
# [[24 24 24]
#  [15 15 15]
#  [ 6  6  6]]

# %% [markdown]
# # Pandas

# %% [markdown]
# We have seen Numpy in the last section. It is good at performing math operation on 2d-arrays of numbers. But the major drawback is, it cannot deal with heterogenous values. So, Pandas dataframes are helpful in that aspect for storing different data types and referring the values like a dict in python instead of just referring each item with index.
#
# [Link to Official Documentation](http://pandas.pydata.org/pandas-docs/version/0.23/dsintro.html)

# %% [markdown]
# ## Series

# %% [markdown]
# Pandas series are almost same as nd arrays in numpy, with a additional inferencing ability with custom labels like *keys* in a *dictionary* in python.

# %%
import numpy as np
import pandas as pd

# %%
#Example

series1 = pd.Series(data = [1,2,3], index = ['key1', 'key2', 'key3'])
series1
# Out:
# key1    1
# key2    2
# key3    3
# dtype: int64

# %% [markdown]
# ### Question 1
#
# Convert a given dict to pd series.
#
# [**Hint:** Use **.Series**]

# %%
d1 = {'a': 1, 'b': 2, 'c': 3}

# %%
d2=pd.Series(d1)
print(d2)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %% [markdown]
# You can directly use numpy functions on series.
# ### Question 2
#
# Find the dot product of both the series create above
#
#
# [ **Hint: ** Use **np.dot()** ]

# %%
print(np.dot(series1,d2))
# Out:
# 14

# %% [markdown]
# ## Dataframes

# %% [markdown]
# A dataframe is a table with labeled columns which can hold different types of data in each column.

# %%
# Example
d1 = {'a': [1,2,3], 'b': [3,4,5], 'c':[6,7,8] }
df1 = pd.DataFrame(d1)
df1
# Out:
#    a  b  c
# 0  1  3  6
# 1  2  4  7
# 2  3  5  8

# %% [markdown]
# ### Question 3
#
# Select second row in the above dataframe df1.

# %%
print(df1.loc[1])
# Out:
# a    2
# b    4
# c    7
# Name: 1, dtype: int64

# %% [markdown]
# ### Question 4
#
# Select column c in second row of df1.
#
# [ **Hint: ** For using labels use **df.loc[row, column]**. For using numeric indexed use **df.iloc[]**. For using mixture of numeric indexes and labels use **df.ix[row, column]** ]

# %%
print(df1['b'])
# Out:
# 0    3
# 1    4
# 2    5
# Name: b, dtype: int64

# %% [markdown]
# ## Using Dataframes on a dataset

# %% [markdown]
# ##### Using the mtcars dataset.
#
# For the below set of questions, we will be using the cars data from [Motor Trend Car Road Tests](http://stat.ethz.ch/R-manual/R-devel/library/datasets/html/mtcars.html)
#
# The data was extracted from the 1974 Motor Trend US magazine, and comprises fuel consumption and 10 aspects of automobile design and performance for 32 automobiles (1973–74 models).
#
#
# Details :
#
# A data frame with 32 observations on 11 (numeric) variables.
#
# [, 1] 	mpg 	Miles/(US) gallon
#
# [, 2] 	cyl 	Number of cylinders
#
# [, 3] 	disp 	Displacement (cu.in.)
#
# [, 4] 	hp 	Gross horsepower
#
# [, 5] 	drat 	Rear axle ratio
#
# [, 6] 	wt 	Weight (1000 lbs)
#
# [, 7] 	qsec 	1/4 mile time
#
# [, 8] 	vs 	Engine (0 = V-shaped, 1 = straight)
#
# [, 9] 	am 	Transmission (0 = automatic, 1 = manual)
#
# [,10] 	gear 	Number of forward gears
#
# [,11] 	carb 	Number of carburetors

# %%
## Reading a dataset from a csv file using pandas.
mtcars = pd.read_csv('mtcars.csv')
mtcars.index = mtcars['name']

# %% [markdown]
# Following questions are based on analysing a particular dataset using dataframes.

# %% [markdown]
# ### Question 5
#
# Check the type and dimensions of given dataset - mtcars.
#
#
# [ **Hint: ** Use **type()** and **df.shape** ]

# %%
print("Type:", type(mtcars))
print("Dimensions:", mtcars.shape)
# Out:
# Type: <class 'pandas.core.frame.DataFrame'>
# Dimensions: (32, 12)

# %% [markdown]
# ### Question 6
#
# Check the first 10 lines and last 10 lines of the given dataset- mtcars.
#
# [**Hint:** Use **.head()** and **.tail()**]

# %%
print("\nTop 10 lines:\n", mtcars.head())
print("\nLast 10 lines:\n", mtcars.tail())
# Out:
# Top 10 lines:
#                  name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
#
# Last 10 lines:
#                name   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %% [markdown]
# ### Question 7
#
# Print all the column labels in the given dataset - mtcars.
#
# [ **Hint: ** Use **df.columns** ]

# %%
print(mtcars.columns)
# Out:
# Index(['name', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %% [markdown]
# ### Question 8

# %% [markdown]
# Select first 6 rows and 3 columns in mtcars dataframe.
#
# **Hint: **
# mtcars.ix[:,:] gives all rows and columns in the dataset.

# %%
print(mtcars.ix[:6,:3])
# Out:
#                 name   mpg  cyl
# 0          Mazda RX4  21.0    6
# 1      Mazda RX4 Wag  21.0    6
# 2         Datsun 710  22.8    4
# 3     Hornet 4 Drive  21.4    6
# 4  Hornet Sportabout  18.7    8
# 5            Valiant  18.1    6
# 6         Duster 360  14.3    8
# C:\Users\Amigo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Lab Brief - Statistical Learning with Python

# %% [markdown]
# ### Part-1

# %% [markdown]
# ## Measures of Data

# %% [markdown]
# Descriptive Statistcs are measures that summarize important features of data. Producing these descriptive statistics is a common first step to take after cleaning and preparing a dataset for further analysis. Examples are like calculating Mean or Median. In this lab, we will be looking into some of these functions and explore several new ones.

# %% [markdown]
# #### Measures of Central Tendency

# %% [markdown]
# Whenever you measure things of the same kind, a fairly large number of such measurements will tend to cluster around the middle value. Such a value is called a measure of "Central Tendency". The other terms that are used synonymously are "Measures of Location", or "Statistical Averages".

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

mtcars = pd.read_csv('mtcars.csv')

# %% [markdown]
# ##### Using the mtcars dataset.
#
# For the below set of questions, we will be using the cars data from [Motor Trend Car Road Tests](http://stat.ethz.ch/R-manual/R-devel/library/datasets/html/mtcars.html)
#
# The data was extracted from the 1974 Motor Trend US magazine, and comprises fuel consumption and 10 aspects of automobile design and performance for 32 automobiles (1973–74 models).
#
#
# Details :
#
# A data frame with 32 observations on 11 (numeric) variables.
#
# [, 1] 	mpg 	Miles/(US) gallon
#
# [, 2] 	cyl 	Number of cylinders
#
# [, 3] 	disp 	Displacement (cu.in.)
#
# [, 4] 	hp 	Gross horsepower
#
# [, 5] 	drat 	Rear axle ratio
#
# [, 6] 	wt 	Weight (1000 lbs)
#
# [, 7] 	qsec 	1/4 mile time
#
# [, 8] 	vs 	Engine (0 = V-shaped, 1 = straight)
#
# [, 9] 	am 	Transmission (0 = automatic, 1 = manual)
#
# [,10] 	gear 	Number of forward gears
#
# [,11] 	carb 	Number of carburetors

# %% [markdown]
# #### Explore the data - Setting the index

# %%
mtcars.index = mtcars["name"]
mtcars.head()
# mtcars.mean() #By default this will give the mean of each column
# Out:
#                                 name   mpg  cyl   disp   hp  drat     wt  \
# name
# Mazda RX4                  Mazda RX4  21.0    6  160.0  110  3.90  2.620
# Mazda RX4 Wag          Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# Datsun 710                Datsun 710  22.8    4  108.0   93  3.85  2.320
# Hornet 4 Drive        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# Hornet Sportabout  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
#
#                     qsec  vs  am  gear  carb
# name
# Mazda RX4          16.46   0   1     4     4
# Mazda RX4 Wag      17.02   0   1     4     4
# Datsun 710         18.61   1   1     4     1
# Hornet 4 Drive     19.44   1   0     3     1
# Hornet Sportabout  17.02   0   0     3     2

# %% [markdown]
# ### Question 1
#
# What is the first car name given in mtcars?
#
# ** Make use of index which has been set previously **
#
# **Hint**: Use .loc function

# %%
print(mtcars.iloc[ 0 ,0])
# Out:
# Mazda RX4

# %% [markdown]
# ### Question 2
# What is the highest difference between the hp and cyl?
#
# **Hint:** You can use **max()** function to find the difference

# %%
mtcars[["hp", "cyl"]].max(axis=0)
# Out:
# hp     335
# cyl      8
# dtype: int64

# %% [markdown]
# ### Question 3
# What are the cars having highest weight(wt) and lowest weight(wt)?
#
# **Hint:** Use idxmax() and idxmin() to locate the row
#
# Use **.iloc** function to print the  row
#
# **Note:** Both idxmax and idxmin belong to pandas

# %%
mtcars[["wt"]].max(axis = 0)
mtcars.loc[mtcars['wt'].idxmax()]
# Out:
# name    Lincoln Continental
# mpg                    10.4
# cyl                       8
# disp                    460
# hp                      215
# drat                      3
# wt                    5.424
# qsec                  17.82
# vs                        0
# am                        0
# gear                      3
# carb                      4
# Name: Lincoln Continental, dtype: object

# %%
mtcars.loc[mtcars['wt'].idxmin()]
# Out:
# Lotus Europa
# name    Lotus Europa
# mpg             30.4
# cyl                4
# disp            95.1
# hp               113
# drat            3.77
# wt             1.513
# qsec            16.9
# vs                 1
# am                 1
# gear               5
# carb               2
# Name: Lotus Europa, dtype: object

# %% [markdown]
# ### Question 4
#
# Find the mean of each row and each column in the given dataset.
#
# **Hint:** Use .mean() function. To operate on rows use **axis=0**, on columns use **axis=1**

# %%
print(mtcars.mean(axis=0))
print(mtcars.mean(axis=1))
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64
# name
# Mazda RX4              29.907273
# Mazda RX4 Wag          29.981364
# Datsun 710             23.598182
# Hornet 4 Drive         38.739545
# Hornet Sportabout      53.664545
# Valiant                35.049091
# Duster 360             59.720000
# Merc 240D              24.634545
# Merc 230               27.233636
# Merc 280               31.860000
# Merc 280C              31.787273
# Merc 450SE             46.430909
# Merc 450SL             46.500000
# Merc 450SLC            46.350000
# Cadillac Fleetwood     66.232727
# Lincoln Continental    66.058545
# Chrysler Imperial      65.972273
# Fiat 128               19.440909
# Honda Civic            17.742273
# Toyota Corolla         18.814091
# Toyota Corona          24.888636
# Dodge Challenger       47.240909
# AMC Javelin            46.007727
# Camaro Z28             58.752727
# Pontiac Firebird       57.379545
# Fiat X1-9              18.928636
# Porsche 914-2          24.779091
# Lotus Europa           24.880273
# Ford Pantera L         60.971818
# Ferrari Dino           34.508182
# Maserati Bora          63.155455
# Volvo 142E             26.262727
# dtype: float64

# %% [markdown]
# ### Question 5
#
# Plot mpg values of mtcards dataframe using matplotlib.
#
# **Hint: Use plt.plot function**

# %%
plt.plot(x='mpg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-154-0d2777229790> in <module>
# ----> 1 mtcars.plt.plot(x='mpg')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'plt'

# %% [markdown]
# ## Part 2

# %% [markdown]
# ## Measures of Dispersion

# %% [markdown]
# Measures of Dispersion (Spread) are statistics that describe how data varies. Measure of dispersion gives us the sense of how much the data tends to diverge from the central tendency.

# %% [markdown]
# ### Question 6
#
# What the range of `mpg` in the given dataset?
#
# **Hint:** Range = max-min

# %%
print(mtcars[["mpg"]].max(axis=0)- mtcars[["mpg"]].min(axis=0))
# Out:
# mpg    23.5
# dtype: float64

# %% [markdown]
# ### Question 7
#
# Calculate the 25th quantile (lower quantile)for `mpg` in the given dataset.
#
# **Hint:** Use **.quantile()**

# %%
mtcars.quantile(.25, axis = 1)
# Out:
# name
# Mazda RX4              3.2600
# Mazda RX4 Wag          3.3875
# Datsun 710             1.6600
# Hornet 4 Drive         2.0000
# Hornet Sportabout      2.5000
# Valiant                1.8800
# Duster 360             3.1050
# Merc 240D              2.5950
# Merc 230               2.5750
# Merc 280               3.6800
# Merc 280C              3.6800
# Merc 450SE             3.0000
# Merc 450SL             3.0000
# Merc 450SLC            3.0000
# Cadillac Fleetwood     2.9650
# Lincoln Continental    3.0000
# Chrysler Imperial      3.1150
# Fiat 128               1.6000
# Honda Civic            1.8075
# Toyota Corolla         1.4175
# Toyota Corona          1.7325
# Dodge Challenger       2.3800
# AMC Javelin            2.5000
# Camaro Z28             3.3650
# Pontiac Firebird       2.5000
# Fiat X1-9              1.4675
# Porsche 914-2          2.0700
# Lotus Europa           1.7565
# Ford Pantera L         3.5850
# Ferrari Dino           3.1950
# Maserati Bora          3.5550
# Volvo 142E             2.3900
# Name: 0.25, dtype: float64

# %% [markdown]
# ### Question 8
#
# Calculate the Inter-Quartile Range(IQR) for `mpg` in the given dataset.

# %% [markdown]
# Interquartile range (IQR) is another common measure of spread. IQR is the distance between the 3rd quartile and the 1st quartile.
#
# **Hint:** IQR = Q3 - Q1

# %% [markdown]
# ### Question 9
#
# Calculate the Variance, Standard Deviation and Median Absolute Deviation for `mpg`.

# %% [markdown]
# Variance and Standard Deviation are two other common measure of dispersion.
#
# **Hint:** Use .var() and .std()

# %% [markdown]
# **Hint:** Median Absolute Deviation - alternative measure of spread based on the median. It is the median of the absolute value of the deviations from the median.

# %%
print("Variance:", mtcars[["mpg"]].var())
print("Standard Deviation:", mtcars[["mpg"]].std())
series = pd.Series(mtcars) 
  
# calling .mad() method 
mtcars.mad('mpg',axis = 1)
# Out:
# Variance: mpg    36.324103
# dtype: float64
# Standard Deviation: mpg    6.026948
# dtype: float64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-188-61bbebf5d551> in <module>
#       1 print("Variance:", mtcars[["mpg"]].var())
#       2 print("Standard Deviation:", mtcars[["mpg"]].std())
# ----> 3 series = pd.Series(mtcars)
#       4
#       5 # calling .mad() method
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     262                                       raise_cast_failure=True)
#     263
# --> 264                 data = SingleBlockManager(data, index, fastpath=True)
#     265
#     266         generic.NDFrame.__init__(self, data, fastpath=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    1479
#    1480         if not isinstance(block, Block):
# -> 1481             block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#    1482
#    1483         self.blocks = [block]
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3093         values = DatetimeArray._simple_new(values, dtype=dtype)
#    3094
# -> 3095     return klass(values, ndim=ndim, placement=placement)
#    3096
#    3097
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#    2629
#    2630         super(ObjectBlock, self).__init__(values, ndim=ndim,
# -> 2631                                           placement=placement)
#    2632
#    2633     @property
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#      85             raise ValueError(
#      86                 'Wrong number of items passed {val}, placement implies '
# ---> 87                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#      88
#      89     def _check_ndim(self, values, ndim):
#
# ValueError: Wrong number of items passed 12, placement implies 32
